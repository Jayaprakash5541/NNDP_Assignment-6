# %% [markdown]
# In class programming:
# 1. Use the use case in the class:
# a. Add more Dense layers to the existing code and check how the accuracy changes.
# 2. Change the data source to Breast Cancer dataset * available in the source code folder and make required
# changes. Report accuracy of the model.
# 3. Normalize the data before feeding the data to the model and check how the normalization change your
# accuracy (code given below).
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# Breast Cancer dataset is designated to predict if a patient has Malignant (M) or Benign = B cancer

# %% [markdown]
# Use Case Description:
#
# Predicting the diabetes disease
# Programming elements:
# Keras Basics
#
# In class programming:
# 1. Use the use case in the class:
# a. Add more Dense layers to the existing code and check how the accuracy changes.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation


dataset = pd.read_csv("/content/diabetes.csv", header=None).values


X_train, X_test, Y_train, Y_test = train_test_split(dataset[:, 0:8], dataset[:, 8], test_size=0.25, random_state=87)

np.random.seed(155)

my_first_nn = Sequential()

my_first_nn.add(Dense(20, input_dim=8, activation='relu'))

my_first_nn.add(Dense(1, activation='sigmoid'))

my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

print(my_first_nn.summary())

loss, accuracy = my_first_nn.evaluate(X_test, Y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 2ms/step - loss: 5.3189 - accuracy: 0.6302
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.9088 - accuracy: 0.6684
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.7744 - accuracy: 0.6319
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.5039 - accuracy: 0.5920
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.3207 - accuracy: 0.6007
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2307 - accuracy: 0.6198
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.1389 - accuracy: 0.6059
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0790 - accuracy: 0.5990
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9905 - accuracy: 0.6302
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9408 - accuracy: 0.6267
# Epoch 11/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9045 - accuracy: 0.6198
# Epoch 12/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8480 - accuracy: 0.6441
# Epoch 13/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8322 - accuracy: 0.6424
# Epoch 14/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8092 - accuracy: 0.6510
# Epoch 15/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7755 - accuracy: 0.6510
# Epoch 16/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7814 - accuracy: 0.6493
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7616 - accuracy: 0.6528
# Epoch 18/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7345 - accuracy: 0.6701
# Epoch 19/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7208 - accuracy: 0.6580
# Epoch 20/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7184 - accuracy: 0.6667
# Epoch 21/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7147 - accuracy: 0.6684
# Epoch 22/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7348 - accuracy: 0.6562
# Epoch 23/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7378 - accuracy: 0.6788
# Epoch 24/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6875 - accuracy: 0.6736
# Epoch 25/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7012 - accuracy: 0.6840
# Epoch 26/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6627 - accuracy: 0.6858
# Epoch 27/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6383 - accuracy: 0.6875
# Epoch 28/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6603 - accuracy: 0.6962
# Epoch 29/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6650 - accuracy: 0.6997
# Epoch 30/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6301 - accuracy: 0.6927
# Epoch 31/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6171 - accuracy: 0.6962
# Epoch 32/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6146 - accuracy: 0.7153
# Epoch 33/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6019 - accuracy: 0.7066
# Epoch 34/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5996 - accuracy: 0.7049
# Epoch 35/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5872 - accuracy: 0.7274
# Epoch 36/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6139 - accuracy: 0.6927
# Epoch 37/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5872 - accuracy: 0.7205
# Epoch 38/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5857 - accuracy: 0.7118
# Epoch 39/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5965 - accuracy: 0.7135
# Epoch 40/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5927 - accuracy: 0.7188
# Epoch 41/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5957 - accuracy: 0.7153
# Epoch 42/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5928 - accuracy: 0.7292
# Epoch 43/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6126 - accuracy: 0.6997
# Epoch 44/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5920 - accuracy: 0.7049
# Epoch 45/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5838 - accuracy: 0.7170
# Epoch 46/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5867 - accuracy: 0.6944
# Epoch 47/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5861 - accuracy: 0.7014
# Epoch 48/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5988 - accuracy: 0.7031
# Epoch 49/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5753 - accuracy: 0.7240
# Epoch 50/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5760 - accuracy: 0.7066
# Epoch 51/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5658 - accuracy: 0.7135
# Epoch 52/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5623 - accuracy: 0.7135
# Epoch 53/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5603 - accuracy: 0.7153
# Epoch 54/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5804 - accuracy: 0.6997
# Epoch 55/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5695 - accuracy: 0.7101
# Epoch 56/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5643 - accuracy: 0.7083
# Epoch 57/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6015 - accuracy: 0.7066
# Epoch 58/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5535 - accuracy: 0.7188
# Epoch 59/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5671 - accuracy: 0.7257
# Epoch 60/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5626 - accuracy: 0.7188
# Epoch 61/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5616 - accuracy: 0.7188
# Epoch 62/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6150 - accuracy: 0.7240
# Epoch 63/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6233 - accuracy: 0.7257
# Epoch 64/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5688 - accuracy: 0.7135
# Epoch 65/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5547 - accuracy: 0.7326
# Epoch 66/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5607 - accuracy: 0.7257
# Epoch 67/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5629 - accuracy: 0.7222
# Epoch 68/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5550 - accuracy: 0.7153
# Epoch 69/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5534 - accuracy: 0.7344
# Epoch 70/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5559 - accuracy: 0.7205
# Epoch 71/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5603 - accuracy: 0.7222
# Epoch 72/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5646 - accuracy: 0.7153
# Epoch 73/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5785 - accuracy: 0.7188
# Epoch 74/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6025 - accuracy: 0.6944
# Epoch 75/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5482 - accuracy: 0.7344
# Epoch 76/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.
# Epoch 90/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6046 - acc: 0.9296
# Epoch 91/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5427 - acc: 0.9319
# Epoch 92/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5636 - acc: 0.9225
# Epoch 93/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5411 - acc: 0.9131
# Epoch 94/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5764 - acc: 0.9296
# Epoch 95/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5430 - acc: 0.9272
# Epoch 96/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7199 - acc: 0.9225
# Epoch 97/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5625 - acc: 0.9319
# Epoch 98/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5117 - acc: 0.9296
# Epoch 99/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5113 - acc: 0.9319
# Epoch 100/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6574 - acc: 0.9319
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 20)                620
#
#  dense_5 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 641 (2.50 KB)
# Trainable params: 641 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 3ms/step - loss: 1.5884 - acc: 0.8252
# [1.5883755683898926, 0.8251748085021973]

# %% [markdown]
# 2nd

# %% [markdown]
# In class programming:
# Use Image Classification on the hand written digits data set (mnist)
# 1. Plot the loss and accuracy for both training data and validation data using the history object in the source
# code.
# 2. Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model
# on that single image.
# 3. We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the
# activation to tanh or sigmoid and see what happens.
# 4. Run the same code without scaling the images and check the performance?

# %% [markdown]
# Use Image Classification on the hand written digits data set (mnist)
# 1. Plot the loss and accuracy for both training data and validation data using the history object in the source
# code.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

(x_train, y_train), (x_val, y_val) = mnist.load_data()

x_train, x_val = x_train / 255.0, x_val / 255.0  # Normalize pixel values to [0, 1]

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, validation_data=(x_val, y_val))

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2954 - accuracy: 0.9138 - val_loss: 0.1386 - val_accuracy: 0.9581
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1409 - accuracy: 0.9585 - val_loss: 0.1012 - val_accuracy: 0.9688
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1066 - accuracy: 0.9679 - val_loss: 0.0872 - val_accuracy: 0.9738
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0866 - accuracy: 0.9724 - val_loss: 0.0785 - val_accuracy: 0.9763
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0731 - accuracy: 0.9770 - val_loss: 0.0738 - val_accuracy: 0.9786
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0657 - accuracy: 0.9786 - val_loss: 0.0686 - val_accuracy: 0.9792
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0581 - accuracy: 0.9813 - val_loss: 0.0652 - val_accuracy: 0.9800
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0499 - accuracy: 0.9839 - val_loss: 0.0711 - val_accuracy: 0.9790
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0488 - accuracy: 0.9839 - val_loss: 0.0700 - val_accuracy: 0.9808
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0447 - accuracy: 0.9852 - val_loss: 0.0698 - val_accuracy: 0.9791

# %% [markdown]
# 2. Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model
# on that single image

# %%
import numpy as np

index = np.random.randint(0, len(x_val))
sample_image = x_val[index]
true_label = y_val[index]

sample_image = np.expand_dims(sample_image, axis=0)

predictions = model.predict(sample_image)

predicted_label = np.argmax(predictions)

class_labels = [str(i) for i in range(10)]

plt.figure(figsize=(4, 4))
plt.imshow(sample_image[0], cmap='gray')
plt.title(f"True Label: {class_labels[true_label]}\nPredicted Label: {class_labels[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 87ms/step

# %% [markdown]
# 3. We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the
# activation to tanh or sigmoid and see what happens.

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

models = []

model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0671, Test accuracy: 0.9795
# 1 hidden layer with sigmoid - Test loss: 0.0584, Test accuracy: 0.9824
# 2 hidden layers with tanh - Test loss: 0.0746, Test accuracy: 0.9801
# 2 hidden layers with sigmoid - Test loss: 0.0694, Test accuracy: 0.9814

# %% [markdown]
# 4. Run the same code without scaling the images and check the performance?

# %%
import keras
from keras.datasets import mnis`t
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

(x_train, y_train), (x_test, y_test) = mnist.load_data()

num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

models = []

model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)

    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.2018, Test accuracy: 0.9375
# 1 hidden layer with sigmoid - Test loss: 0.1373, Test accuracy: 0.9587
# 2 hidden layers with tanh - Test loss: 0.1418, Test accuracy: 0.9558
# 2 hidden layers with sigmoid - Test loss: 0.1013, Test accuracy: 0.9684
